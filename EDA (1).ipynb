# %%
# import the neccesary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### LOAD DATASET & DATA EXPLORATION

# %%
# load the dataset
housing_data = pd.read_csv(r"C:\Users\Nisha Pal\Downloads\housing_data.csv")
housing_data.head()
# Out:
#    Unnamed: 0 MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0           0       SC60       RL           65     8450   Pave   NaN      Reg
# 1           1       SC20       RL           80     9600   Pave   NaN      Reg
# 2           2       SC60       RL           68    11250   Pave   NaN      IR1
# 3           3       SC70       RL           60     9550   Pave   NaN      IR1
# 4           4       SC60       RL           84    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0     No    No          No       0    Feb
# 1         Lvl    AllPub  ...        0     No    No          No       0    May
# 2         Lvl    AllPub  ...        0     No    No          No       0    Sep
# 3         Lvl    AllPub  ...        0     No    No          No       0    Feb
# 4         Lvl    AllPub  ...        0     No    No          No       0    Dec
#
# ...

# %% [markdown]
# ### TAIL

# %%
housing_data.head()
# Out:
#    Unnamed: 0 MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0           0       SC60       RL           65     8450   Pave   NaN      Reg
# 1           1       SC20       RL           80     9600   Pave   NaN      Reg
# 2           2       SC60       RL           68    11250   Pave   NaN      IR1
# 3           3       SC70       RL           60     9550   Pave   NaN      IR1
# 4           4       SC60       RL           84    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0     No    No          No       0    Feb
# 1         Lvl    AllPub  ...        0     No    No          No       0    May
# 2         Lvl    AllPub  ...        0     No    No          No       0    Sep
# 3         Lvl    AllPub  ...        0     No    No          No       0    Feb
# 4         Lvl    AllPub  ...        0     No    No          No       0    Dec
#
# ...

# %% [markdown]
# ### NUMBER OF ROW AND COLUMNS

# %%
housing_data.shape
# Out:
# (1460, 81)

# %% [markdown]
# ### DIMENTION OF DATASET

# %%
housing_data.ndim
# Out:
# 2

# %%
duplicates = housing_data.duplicated()
duplicates.sum()
# Out:
# 0

# %%
duplicate_subset = housing_data[housing_data.duplicated(subset=['LotFrontage','LotArea'], keep=False)]
duplicate_subset
# Out:
#       Unnamed: 0 MSSubClass MSZoning  LotFrontage  LotArea Street Alley  \
# 0              0       SC60       RL           65     8450   Pave   NaN
# 1              1       SC20       RL           80     9600   Pave   NaN
# 8              8       SC50       RM           51     6120   Pave   NaN
# 15            15       SC45       RM           51     6120   Pave   NaN
# 18            18       SC20       RL           66    13695   Pave   NaN
# ...          ...        ...      ...          ...      ...    ...   ...
# 1449        1449      SC180       RM           21     1533   Pave   NaN
# 1450        1450       SC90       RL           60     9000   Pave   NaN
# 1452        1452      SC180       RM           35     3675   Pave   NaN
# 1454        1454       SC20       FV           62     7500   Pave  Pave
# 1459        1459       SC20       RL           75     9937   Pave   NaN
#
#      LotShape LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature  \
# ...

# %%
housing_data = housing_data.drop_duplicates()
housing_data.count()
# Out:
# Unnamed: 0       1460
# MSSubClass       1460
# MSZoning         1460
# LotFrontage      1460
# LotArea          1460
#                  ...
# MoSold           1460
# YrSold           1460
# SaleType         1460
# SaleCondition    1460
# SalePrice        1460
# Length: 81, dtype: int64

# %% [markdown]
# ### SUMMARY OF DATASET

# %%
# Summary statistics
housing_data.describe()
# Out:
#         Unnamed: 0  LotFrontage        LotArea  OverallQual  OverallCond  \
# count  1460.000000  1460.000000    1460.000000  1460.000000  1460.000000
# mean    729.500000    57.623288   10516.828082     6.099315     5.575342
# std     421.610009    34.664304    9981.264932     1.382997     1.112799
# min       0.000000     0.000000    1300.000000     1.000000     1.000000
# 25%     364.750000    42.000000    7553.500000     5.000000     5.000000
# 50%     729.500000    63.000000    9478.500000     6.000000     5.000000
# 75%    1094.250000    79.000000   11601.500000     7.000000     6.000000
# max    1459.000000   313.000000  215245.000000    10.000000     9.000000
#
#          YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1   BsmtFinSF2  ...  \
# count  1460.000000   1460.000000  1460.000000  1460.000000  1460.000000  ...
# mean   1971.267808   1984.865753   103.117123   443.639726    46.549315  ...
# std      30.202904     20.645407   180.731373   456.098091   161.319273  ...
# ...

# %% [markdown]
# ### INFOMATION OF DATASET

# %%
housing_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     1460 non-null   int64
#  1   MSSubClass     1460 non-null   object
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1460 non-null   int64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %% [markdown]
# # Transpose the data to have a different look at the data

# %%
housing_data.head().T
# Out:
#                     0       1       2        3       4
# Unnamed: 0          0       1       2        3       4
# MSSubClass       SC60    SC20    SC60     SC70    SC60
# MSZoning           RL      RL      RL       RL      RL
# LotFrontage        65      80      68       60      84
# LotArea          8450    9600   11250     9550   14260
# ...               ...     ...     ...      ...     ...
# MoSold            Feb     May     Sep      Feb     Dec
# YrSold           2008    2007    2008     2006    2008
# SaleType           WD      WD      WD       WD      WD
# SaleCondition  Normal  Normal  Normal  Abnorml  Normal
# SalePrice      208500  181500  223500   140000  250000
#
# [81 rows x 5 columns]

# %% [markdown]
# ### COLUMNS IN DATASET

# %%
columns = housing_data.columns
columns
# Out:
# Index(['Unnamed: 0', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea',
#        'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
# ...

# %%
housing_data.shape
# Out:
# (1460, 81)

# %%
housing_data = housing_data.drop_duplicates()
housing_data.count()
# Out:
# Unnamed: 0       1460
# MSSubClass       1460
# MSZoning         1460
# LotFrontage      1460
# LotArea          1460
#                  ...
# MoSold           1460
# YrSold           1460
# SaleType         1460
# SaleCondition    1460
# SalePrice        1460
# Length: 81, dtype: int64

# %%
housing_data.isnull().sum()
# Out:
# Unnamed: 0       0
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
#                 ..
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# SalePrice        0
# Length: 81, dtype: int64

# %% [markdown]
# #### MSSubClass:identifies the type of dwelling involvedin the sale

# %% [markdown]
# #### sc20=1-story 1946 and newer all styles

# %%
housing_data['MSSubClass'] = housing_data['MSSubClass'].replace({'SC20':'story 1946 and newer all styles'})

# %%
housing_data
# Out:
#       Unnamed: 0                       MSSubClass MSZoning  LotFrontage  \
# 0              0                             SC60       RL           65
# 1              1  story 1946 and newer all styles       RL           80
# 2              2                             SC60       RL           68
# 3              3                             SC70       RL           60
# 4              4                             SC60       RL           84
# ...          ...                              ...      ...          ...
# 1455        1455                             SC60       RL           62
# 1456        1456  story 1946 and newer all styles       RL           85
# 1457        1457                             SC70       RL           66
# 1458        1458  story 1946 and newer all styles       RL           68
# 1459        1459  story 1946 and newer all styles       RL           75
#
#       LotArea Street Alley LotShape LandContour Utilities  ... PoolArea  \
# ...

# %% [markdown]
# #### sc20=1-story 1946 and older

# %%
housing_data['MSSubClass'] = housing_data['MSSubClass'].replace({'SC30':'story 1946 and older'})

# %%
housing_data
# Out:
#       Unnamed: 0                       MSSubClass MSZoning  LotFrontage  \
# 0              0                             SC60       RL           65
# 1              1  story 1946 and newer all styles       RL           80
# 2              2                             SC60       RL           68
# 3              3                             SC70       RL           60
# 4              4                             SC60       RL           84
# ...          ...                              ...      ...          ...
# 1455        1455                             SC60       RL           62
# 1456        1456  story 1946 and newer all styles       RL           85
# 1457        1457                             SC70       RL           66
# 1458        1458  story 1946 and newer all styles       RL           68
# 1459        1459  story 1946 and newer all styles       RL           75
#
#       LotArea Street Alley LotShape LandContour Utilities  ... PoolArea  \
# ...

# %% [markdown]
# ### RENAME THE COLUMNS MSSubClass TO MS Sub Class

# %%
housing_data.rename(columns={'MSSubClass': 'Type of Dwelling'}, inplace = True)

# %%
housing_data
# Out:
#       Unnamed: 0                 Type of Dwelling MSZoning  LotFrontage  \
# 0              0                             SC60       RL           65
# 1              1  story 1946 and newer all styles       RL           80
# 2              2                             SC60       RL           68
# 3              3                             SC70       RL           60
# 4              4                             SC60       RL           84
# ...          ...                              ...      ...          ...
# 1455        1455                             SC60       RL           62
# 1456        1456  story 1946 and newer all styles       RL           85
# 1457        1457                             SC70       RL           66
# 1458        1458  story 1946 and newer all styles       RL           68
# 1459        1459  story 1946 and newer all styles       RL           75
#
#       LotArea Street Alley LotShape LandContour Utilities  ... PoolArea  \
# ...

# %% [markdown]
# ### UNIQUE VALUES OF Type of Dwelling

# %%
housing_data['Type of Dwelling'].unique()
# Out:
# array(['SC60', 'story 1946 and newer all styles', 'SC70', 'SC50', 'SC190',
#        'SC45', 'SC90', 'SC120', 'story 1946 and older', 'SC85', 'SC80',
#        'SC160', 'SC75', 'SC180', 'SC40'], dtype=object)

# %% [markdown]
# ### VALUES COUNTS OF Type of Dwelling

# %%
housing_data['Type of Dwelling'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Type of Dwelling'>

# %% [markdown]
# ### MSZoning:identifies the genral zoning classification of the sale

# %% [markdown]
# #### VALUE COUNTS OF MSZoning TO CHECK ZONES

# %%
housing_data['MSZoning'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='MSZoning'>

# %% [markdown]
# ### MEANS THERE ARE ONLY 5 ZONES, SO WE WILL WORK ON THEM

# %% [markdown]
# #### RL = RESIDENCIAL LOW DENSITY

# %%
housing_data['MSZoning'] = housing_data['MSZoning'].replace({'RL' :'RESIDENCIAL LOW DENSITY'})

# %%
housing_data
# Out:
#       Unnamed: 0                 Type of Dwelling                 MSZoning  \
# 0              0                             SC60  RESIDENCIAL LOW DENSITY
# 1              1  story 1946 and newer all styles  RESIDENCIAL LOW DENSITY
# 2              2                             SC60  RESIDENCIAL LOW DENSITY
# 3              3                             SC70  RESIDENCIAL LOW DENSITY
# 4              4                             SC60  RESIDENCIAL LOW DENSITY
# ...          ...                              ...                      ...
# 1455        1455                             SC60  RESIDENCIAL LOW DENSITY
# 1456        1456  story 1946 and newer all styles  RESIDENCIAL LOW DENSITY
# 1457        1457                             SC70  RESIDENCIAL LOW DENSITY
# 1458        1458  story 1946 and newer all styles  RESIDENCIAL LOW DENSITY
# 1459        1459  story 1946 and newer all styles  RESIDENCIAL LOW DENSITY
#
# ...

# %% [markdown]
# ##### RM =RESIDENCIAL MEDIUM DENSITY

# %%
housing_data['MSZoning'] = housing_data['MSZoning'].replace({'RM':'RESIDENCIAL MEDIUM DENSITY'})

# %% [markdown]
# #### FV = FLOATING VILLAGE REGIDENTIAL

# %%
housing_data['MSZoning'] = housing_data['MSZoning'].replace({'FV':'FLOATING VILLAGE REGIDENTIAL'})

# %% [markdown]
# ##### RH = RESIDENTIAL HIGH-DENSITY

# %%
housing_data['MSZoning'] = housing_data['MSZoning'].replace({'RH':'RESIDENTIAL HIGH-DENSITY'})

# %% [markdown]
# #### C= COMMERCIAL

# %%
housing_data['MSZoning'] = housing_data['MSZoning'].replace({'C(ALL)':'COMMERCIAL'})

# %% [markdown]
# #### RENAME THE COLUMNS MSZoning TO General Zone Classification

# %%
housing_data.rename(columns={'MSZoning':'General Zone Classification'},inplace=True)

# %%
housing_data
# Out:
#       Unnamed: 0                 Type of Dwelling General Zone Classification  \
# 0              0                             SC60     RESIDENCIAL LOW DENSITY
# 1              1  story 1946 and newer all styles     RESIDENCIAL LOW DENSITY
# 2              2                             SC60     RESIDENCIAL LOW DENSITY
# 3              3                             SC70     RESIDENCIAL LOW DENSITY
# 4              4                             SC60     RESIDENCIAL LOW DENSITY
# ...          ...                              ...                         ...
# 1455        1455                             SC60     RESIDENCIAL LOW DENSITY
# 1456        1456  story 1946 and newer all styles     RESIDENCIAL LOW DENSITY
# 1457        1457                             SC70     RESIDENCIAL LOW DENSITY
# 1458        1458  story 1946 and newer all styles     RESIDENCIAL LOW DENSITY
# 1459        1459  story 1946 and newer all styles     RESIDENCIAL LOW DENSITY
#
# ...

# %% [markdown]
# ###  unique values of General Zone Classification columns

# %%
housing_data['General Zone Classification'].unique()
# Out:
# array(['RESIDENCIAL LOW DENSITY', 'RESIDENCIAL MEDIUM DENSITY', 'C (all)',
#        'FLOATING VILLAGE REGIDENTIAL', 'RESIDENTIAL HIGH-DENSITY'],
#       dtype=object)

# %% [markdown]
# #### LotFrontage linear feet of street connect to the property

# %% [markdown]
# #### rename the columns LotFrontage to linear feet of steet

# %%
housing_data.rename(columns={'LotFrontage':'linear feet of steet'},inplace=True)

# %%
housing_data
# Out:
#       Unnamed: 0                 Type of Dwelling General Zone Classification  \
# 0              0                             SC60     RESIDENCIAL LOW DENSITY
# 1              1  story 1946 and newer all styles     RESIDENCIAL LOW DENSITY
# 2              2                             SC60     RESIDENCIAL LOW DENSITY
# 3              3                             SC70     RESIDENCIAL LOW DENSITY
# 4              4                             SC60     RESIDENCIAL LOW DENSITY
# ...          ...                              ...                         ...
# 1455        1455                             SC60     RESIDENCIAL LOW DENSITY
# 1456        1456  story 1946 and newer all styles     RESIDENCIAL LOW DENSITY
# 1457        1457                             SC70     RESIDENCIAL LOW DENSITY
# 1458        1458  story 1946 and newer all styles     RESIDENCIAL LOW DENSITY
# 1459        1459  story 1946 and newer all styles     RESIDENCIAL LOW DENSITY
#
# ...

# %% [markdown]
# #### LotArea: lotsize in square feet

# %% [markdown]
# #### Rename the column LotArea to plot size in square feet

# %%
housing_data.rename(columns={'LotArea':'plot size in square feet'},inplace=True)

# %%
housing_data['plot size in square feet'].value_counts()
# Out:
# plot size in square feet
# 7200     25
# 9600     24
# 6000     17
# 9000     14
# 8400     14
#          ..
# 14601     1
# 13682     1
# 4058      1
# 17104     1
# 9717      1
# Name: count, Length: 1073, dtype: int64

# %%
housing_data.head(2)
# Out:
#    Unnamed: 0                 Type of Dwelling General Zone Classification  \
# 0           0                             SC60     RESIDENCIAL LOW DENSITY
# 1           1  story 1946 and newer all styles     RESIDENCIAL LOW DENSITY
#
#    linear feet of steet  plot size in square feet Street Alley LotShape  \
# 0                    65                      8450   Pave   NaN      Reg
# 1                    80                      9600   Pave   NaN      Reg
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0     No    No          No       0    Feb
# 1         Lvl    AllPub  ...        0     No    No          No       0    May
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
#
# [2 rows x 81 columns]

# %% [markdown]
# #### street:Type of road access to property
#
# #### Grvl = Gravel
#
# #### Pave = Paved

# %%
housing_data['Alley']=housing_data['Alley'].replace({'Grvl':'Gravel','Pave':'paved'})

# %% [markdown]
# NA = No alley access

# %%
housing_data['Alley'] = housing_data['Alley'].fillna('No Alley Access')

# %%
housing_data.rename(columns={'Alley':'Type of Alley'},inplace=True)

# %%
housing_data['Type of Alley'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Type of Alley'>

# %% [markdown]
# Unique Values of Type of Alley Column

# %%
housing_data['Type of Alley'].unique()
# Out:
# array(['No Alley Access', 'Gravel', 'paved'], dtype=object)

# %%
housing_data.head(2)
# Out:
#    Unnamed: 0                 Type of Dwelling General Zone Classification  \
# 0           0                             SC60     RESIDENCIAL LOW DENSITY
# 1           1  story 1946 and newer all styles     RESIDENCIAL LOW DENSITY
#
#    linear feet of steet  plot size in square feet Street    Type of Alley  \
# 0                    65                      8450   Pave  No Alley Access
# 1                    80                      9600   Pave  No Alley Access
#
#   LotShape LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature  \
# 0      Reg         Lvl    AllPub  ...        0     No    No          No
# 1      Reg         Lvl    AllPub  ...        0     No    No          No
#
#   MiscVal MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0       0    Feb   2008        WD         Normal     208500
# 1       0    May   2007        WD         Normal     181500
#
# [2 rows x 81 columns]

# %% [markdown]
# #### LotShape:General shape of property
#
# #### Reg =Regular
# #### IR1=slightly irregular
# #### IR2=Moderately Irregular
# #### IR3=Irregular

# %%
housing_data['LotShape'] = housing_data['LotShape'].replace({'Reg':'Regular','IR1':'Slightly Irregular','IR2':'Moderately Irregular','IR3':'Irregular'})

# %%
housing_data.rename(columns={'LotShape':'Shape of Property'},inplace=True)

# %%
housing_data['Shape of Property'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Shape of Property'>

# %% [markdown]
# Unique values of shape of property Column

# %%
housing_data['Shape of Property'].unique()
# Out:
# array(['Regular', 'Slightly Irregular', 'Moderately Irregular',
#        'Irregular'], dtype=object)

# %%
housing_data[0:2]
# Out:
#    Unnamed: 0                 Type of Dwelling General Zone Classification  \
# 0           0                             SC60     RESIDENCIAL LOW DENSITY
# 1           1  story 1946 and newer all styles     RESIDENCIAL LOW DENSITY
#
#    linear feet of steet  plot size in square feet Street    Type of Alley  \
# 0                    65                      8450   Pave  No Alley Access
# 1                    80                      9600   Pave  No Alley Access
#
#   Shape of Property LandContour Utilities  ... PoolArea PoolQC Fence  \
# 0           Regular         Lvl    AllPub  ...        0     No    No
# 1           Regular         Lvl    AllPub  ...        0     No    No
#
#   MiscFeature MiscVal MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0          No       0    Feb   2008        WD         Normal     208500
# 1          No       0    May   2007        WD         Normal     181500
#
# [2 rows x 81 columns]

# %% [markdown]
# LandContour:Flatness of the property
#
# #### Lvl = Near Flat/level
# #### Bnk = banked-Quick and significant rise from street grade to building
# #### HLS=Hillside-Significant slope from side to side
# #### Low = Depression

# %%
housing_data['LandContour'] = housing_data['LandContour'].replace({'Lvl':'Near Flat level','Bnk':'Banked','HLS':'Hillside','Low':'Depression'})

# %%
housing_data.rename(columns={'LandContour':'Flatness of Property'},inplace=True)

# %%
housing_data['Flatness of Property'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Flatness of Property'>

# %%
housing_data[0:2]
# Out:
#    Unnamed: 0                 Type of Dwelling General Zone Classification  \
# 0           0                             SC60     RESIDENCIAL LOW DENSITY
# 1           1  story 1946 and newer all styles     RESIDENCIAL LOW DENSITY
#
#    linear feet of steet  plot size in square feet Street    Type of Alley  \
# 0                    65                      8450   Pave  No Alley Access
# 1                    80                      9600   Pave  No Alley Access
#
#   Shape of Property Flatness of Property Utilities  ... PoolArea PoolQC Fence  \
# 0           Regular      Near Flat level    AllPub  ...        0     No    No
# 1           Regular      Near Flat level    AllPub  ...        0     No    No
#
#   MiscFeature MiscVal MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0          No       0    Feb   2008        WD         Normal     208500
# 1          No       0    May   2007        WD         Normal     181500
#
# [2 rows x 81 columns]

# %% [markdown]
# Utilities:Type of utilities avialble
#
# AllPub = All public Utilities(E,G,W,&S)
#
# NoSewr = Electricty,Gas,and Water(Septic Tank)
#
# NoSeWa =Electricity and Gas only
#
# ELO = Electricity only

# %%
housing_data['Utilities'] = housing_data['Utilities'].replace({'AllPub':'All Public Utilities','NoSewa':'Electricty,Gas,and Water','NoSeWa':'Electricity and Gas only'})

# %%
housing_data.rename(columns={'Utilities':'Type of utilities avialble'},inplace=True)

# %%
housing_data['Type of utilities avialble'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Type of utilities avialble'>

# %%
sns.relplot(data = housing_data,x='SalePrice',y=)
# Out:
#   Cell In[64], line 1
#     sns.relplot(data = housing_data,x='SalePrice',y=)
#                                                     ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Univariate Analysis

# %%
# Boxplot of the price
sns.boxplot(x = housing_data['SalePrice'])

plt.show()

# %% [markdown]
# ## Describe the dataset and remove outliers

# %%
housing_data.describe().iloc[:,:10]
# Out:
#         Unnamed: 0  linear feet of steet  plot size in square feet  \
# count  1366.000000           1366.000000               1366.000000
# mean    733.890922             55.785505              10095.015373
# std     422.983300             34.258318               8396.742642
# min       0.000000              0.000000               1300.000000
# 25%     367.250000             40.000000               7392.250000
# 50%     740.500000             60.000000               9245.000000
# 75%    1099.750000             76.000000              11233.250000
# max    1459.000000            313.000000             164660.000000
#
#        OverallQual  OverallCond    YearBuilt  YearRemodAdd   MasVnrArea  \
# count  1366.000000  1366.000000  1366.000000   1366.000000  1366.000000
# mean      5.928258     5.598097  1969.432650   1983.605417    85.270864
# std       1.240043     1.120686    29.902495     20.682925   154.425035
# min       1.000000     1.000000  1872.000000   1950.000000     0.000000
# ...

# %%
housing_data.describe().iloc[:,10:20]
# Out:
#          BsmtUnfSF  TotalBsmtSF     1stFlrSF     2ndFlrSF  LowQualFinSF  \
# count  1366.000000  1366.000000  1366.000000  1366.000000   1366.000000
# mean    555.758419  1012.691069  1122.803807   329.200586      5.827965
# std     425.159514   402.915750   354.177881   414.316220     47.852525
# min       0.000000     0.000000   334.000000     0.000000      0.000000
# 25%     217.250000   780.750000   864.000000     0.000000      0.000000
# 50%     474.000000   960.000000  1057.000000     0.000000      0.000000
# 75%     803.750000  1233.500000  1335.500000   715.500000      0.000000
# max    2042.000000  6110.000000  4692.000000  1818.000000    528.000000
#
#          GrLivArea  BsmtFullBath  BsmtHalfBath     FullBath     HalfBath
# count  1366.000000   1366.000000   1366.000000  1366.000000  1366.000000
# mean   1457.832357      0.401903      0.060029     1.528551     0.366032
# std     470.117596      0.512378      0.243716     0.533416     0.499805
# ...

# %%
housing_data.describe().iloc[:,20:]
# Out:
#        BedroomAbvGr  KitchenAbvGr  TotRmsAbvGrd   Fireplaces  GarageYrBlt  \
# count   1366.000000   1366.000000   1366.000000  1366.000000  1285.000000
# mean       2.857980      1.049780      6.383602     0.570278  1976.884825
# std        0.804041      0.227448      1.530398     0.629409    24.612020
# min        0.000000      0.000000      2.000000     0.000000  1900.000000
# 25%        2.000000      1.000000      5.000000     0.000000  1960.000000
# 50%        3.000000      1.000000      6.000000     0.000000  1977.000000
# 75%        3.000000      1.000000      7.000000     1.000000  2000.000000
# max        8.000000      3.000000     14.000000     3.000000  2010.000000
#
#         GarageCars   GarageArea   WoodDeckSF  OpenPorchSF  EnclosedPorch  \
# count  1366.000000  1366.000000  1366.000000  1366.000000    1366.000000
# mean      1.696193   452.119327    86.955344    43.589312      22.800146
# std       0.712484   200.929637   119.689318    64.281470      61.981909
# ...

# %% [markdown]
# #### HISTOGRAM OF PRICE ANALYSIS

# %%
sns.histplot(data=housing_data,x='SalePrice',bins = 20,hue = 'Shape of Property',element='step')
plt.title('histogram of price distribution with miscellaneous features\n')
plt.show()

# %%
sns.violinplot(data = housing_data,y = 'SalePrice')
plt.title('YrSold\n')
plt.show()

# %%
housing_data.to_csv('final data.csv')

# %% [markdown]
# ### Data Info

# %%
housing_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1366 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Unnamed: 0                   1366 non-null   int64
#  1   Type of Dwelling             1366 non-null   object
#  2   General Zone Classification  1366 non-null   object
#  3   linear feet of steet         1366 non-null   int64
#  4   plot size in square feet     1366 non-null   int64
#  5   Street                       1366 non-null   object
#  6   Type of Alley                1366 non-null   object
#  7   Shape of Property            1366 non-null   object
#  8   Flatness of Property         1366 non-null   object
#  9   Type of utilities avialble   1366 non-null   object
#  10  LotConfig                    1366 non-null   object
#  11  LandSlope                    1366 non-null   object
#  12  Neighborhood                 1366 non-null   object
# ...

# %% [markdown]
# #### Univariate Analysis - numeric variables

# %%
numeric_variables = housing_data.select_dtypes(include=['int64', 'float64']).columns
for col in numeric_variables:
    plt.figure(figsize=(8, 6))
    sns.histplot(housing_data[col], kde=True, element='step')
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.show()

# %%
# Boxplot to give the price column
sns.boxplot(x = housing_data['SalePrice'])
plt.show()
print(housing_data.shape)
# Out:
# (1460, 81)

# %% [markdown]
# #### make function to handle outliers of columns with IQR Method by capping

# %%
def iqr_technique(DFcolumn):
  Q1 = np.percentile(DFcolumn, 25)
  Q3 = np.percentile(DFcolumn, 75)
  IQR = Q3 - Q1
  lower_range = Q1 - (1.5 * IQR)
  upper_range = Q3 + (1.5 * IQR)
  return lower_range, upper_range

# %%
lower_range, upper_range = iqr_technique(housing_data['SalePrice'])
housing_data = housing_data[(housing_data.SalePrice > lower_range) & (housing_data.SalePrice<upper_range)]

# %%
# Check that the outliers are removed.
sns.boxplot(x = housing_data['SalePrice'])
print(housing_data.shape)
# Out:
# (1399, 81)

# %%
print(housing_data['SalePrice'].max())
# Out:
# 340000

# %%
# Distribution of the prices
plt.figure(figsize=(20,25))
sns.set_theme(style="darkgrid")
sns.distplot(housing_data['SalePrice'], color=('r'))
plt.xlabel("SalePrice", fontsize=26)
plt.ylabel("Density", fontsize=26)
plt.title("Distribution of housing SalePrice", fontsize = 26)
plt.show()

# %% [markdown]
# ### 2. Total Listinf/property count in each neighbourhood group using count plot

# %%
# Count listings in each Neighborhood and store in pandas series
counts = housing_data['Neighborhood'].value_counts()

# Reset the cindes of the series so that the Neighborhood become columns in the resulting dataframe
Top_Neighborhood = counts.reset_index()

# Rename the columns of the dataframe to be more descriptive
Top_Neighborhood.columns = ['Neighborhood', 'HouseStyle']

# Display the results
Top_Neighborhood
# Out:
#    Neighborhood  HouseStyle
# 0         NAmes         224
# 1       CollgCr         148
# 2       OldTown         112
# 3       Edwards         100
# 4       Somerst          84
# 5       Gilbert          78
# 6        Sawyer          74
# 7        NWAmes          73
# 8       SawyerW          59
# 9       BrkSide          58
# 10      NridgHt          50
# 11      Mitchel          49
# 12      Crawfor          48
# 13       IDOTRR          37
# 14       Timber          35
# 15      NoRidge          30
# 16      ClearCr          28
# 17        SWISU          25
# 18      MeadowV          17
# 19      Blmngtn          17
# 20      StoneBr          16
# 21       BrDale          16
# 22      Veenker          10
# 23      NPkVill           9
# 24      Blueste           2

# %%
# Set the size
plt.figure(figsize=(20,25))

#create a count plot of the Neighborhood data
sns.countplot(housing_data['Neighborhood'])

# Set title
plt.title('Neighborhood HouseStyle in NYC',fontsize=26)

# Set the xlabel
plt.xlabel('Neighborhood',fontsize=26)

#Set the y label
plt.ylabel('HouseStyle ',fontsize=26)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[75], line 5
#       2 plt.figure(figsize=(20,25))
#       4 #create a count plot of the Neighborhood data
# ----> 5 sns.countplot(housing_data['Neighborhood'])
#       7 # Set title
#       8 plt.title('Neighborhood HouseStyle in NYC',fontsize=26)
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:2943, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2940 elif x is not None and y is not None:
#    2941     raise ValueError("Cannot pass values for both `x` and `y`")
# -> 2943 plotter = _CountPlotter(
#    2944     x, y, hue, data, order, hue_order,
#    2945     estimator, errorbar, n_boot, units, seed,
#    2946     orient, color, palette, saturation,
#    2947     width, errcolor, errwidth, capsize, dodge
#    2948 )
# ...

# %% [markdown]
# ### 3. Average price of Each Enighbourhood group using Point Plot

# %%
housing_data.head()
# Out:
#    Unnamed: 0                 Type of Dwelling General Zone Classification  \
# 0           0                             SC60     RESIDENCIAL LOW DENSITY
# 1           1  story 1946 and newer all styles     RESIDENCIAL LOW DENSITY
# 2           2                             SC60     RESIDENCIAL LOW DENSITY
# 3           3                             SC70     RESIDENCIAL LOW DENSITY
# 4           4                             SC60     RESIDENCIAL LOW DENSITY
#
#    linear feet of steet  plot size in square feet Street    Type of Alley  \
# 0                    65                      8450   Pave  No Alley Access
# 1                    80                      9600   Pave  No Alley Access
# 2                    68                     11250   Pave  No Alley Access
# 3                    60                      9550   Pave  No Alley Access
# 4                    84                     14260   Pave  No Alley Access
#
# ...

# %%
# Group the housing dataset by Neighborhood and calculate the mean of each group
#grouped = housing_data.groupby("Neighborhood").mean()
grouped = housing_data.groupby("Neighborhood")["SalePrice"].mean()
# Reset the indes of the grouped data so that the Neighborhood becomes a column
Neighborhood_avg_SalePrice = grouped.reset_index()

#Rename the price to 'avg_SalePrice'
Neighborhood_avg_SalePrice = round(Neighborhood_avg_SalePrice.rename(columns={"SalePrice": 'avg_SalePrice'}), 50)


# Select only the 'Neighborhood', and the avg_SalePrice
Neighborhood_avg_SalePrice[['Neighborhood', 'avg_SalePrice']].head()
# Out:
#   Neighborhood  avg_SalePrice
# 0      Blmngtn  194870.882353
# 1      Blueste  137500.000000
# 2       BrDale  104493.750000
# 3      BrkSide  124834.051724
# 4      ClearCr  212565.428571

# %%
# Import mean from the statistics module
from statistics import mean

# Create the pointplot
sns.pointplot(x = 'Neighborhood', y = 'SalePrice', data=housing_data, estimator = np.mean)

# Add axis and labels
plt.xlabel("Neighborhood")

plt.ylabel('Average SalePrice')

plt.title('Average SalePrice by the Neighborhood')
# Out:
# Text(0.5, 1.0, 'Average SalePrice by the Neighborhood')

# %%
# SalePrice distribution using violin plot
ax = sns.violinplot(x = 'Neighborhood', y = 'SalePrice', data = housing_data)
